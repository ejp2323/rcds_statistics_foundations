# %% [markdown]
# ### Box Plot
# A box plot gives a low-resolution view of the location of the data, and its *overall* dispersion. It can be a useful summary, particularly as a way to compare subpopulations.

# %%
penguins['body_mass_g'] \
    .plot.box(legend=True)
plt.show()

# %% [markdown]
# ### Violin plot

# %% [markdown]
# ### Error bars
